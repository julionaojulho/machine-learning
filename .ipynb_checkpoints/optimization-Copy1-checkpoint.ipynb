# %% [markdown]
# ## Otimização de projeto em engenharia mecânica

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import solve
# %matplotlib inline

# %% [markdown]
# ### Função, gradiente e hessiana
#
# * $f(x)$ - função a ser minimizada
# * $\nabla f(x)$ - gradiente de $f(x)$
# * $\nabla^2 f(x)$ - hessiana de $f(x)$

# %%
def func(x0):
    x1, x2 = x0[0],x0[1]
    return((1 - x1)**2 + 100* (x2 - x1**2)**2)

def grad(x0):
    x1, x2 = x0[0],x0[1]
    return(np.array([400*x1**3 - 400*x1*x2 +\
                     2*x1 - 2, 200*x2 -\
                     200*x1**2]).reshape((2,1)))

def hess(x0):
    x1, x2 = x0[0],x0[1]
    return(np.array([1200*x1**2 - 400*x2 + 2,
                    -400*x1, -400*x1,
                     200]).reshape((2,2)))

def direction(x0,flag,df=0,alpha=1,d2f=0):
    if flag == 0:
        d = -grad(x0).T
    elif flag == 1:
        df = grad(x0)
        if type(d2f) == int:
            d2f = hess(x0)
        try:
            d = solve(d2f,-df,sym_pos=True,check_finite=True).T
        except:
            d2f = np.eye(2)
            d = solve(d2f,-df).T
    return(d)

def hess_num(x0,df,alpha,d,H=np.eye(2)):
    try:
        solve(H,-df,check_finite=True).T
    except:
        H = np.eye(2)
    c = grad(x0 + alpha * d)
    y = c - df
    s = alpha * d
    #print(c,'c\n',y,'y\n',s,'s\n',d,'d\n',df)
    D = np.matmul(y,y.T) / np.dot(y.T[0],s)
    E = np.matmul(df,df.T) / np.dot(df.T[0],d)
    return(H + D + E)

def step(x0,d,inc=1e-6):
    soma = 0
    f1 = func(x0)
    m = (np.sqrt(5) + 1) / 2    
    for i in range(100):
        soma += m**i
        if func(x0+inc*(soma)*d) > f1 and i > 0:
            #print(x0+inc*(soma)*d,'aa','\n',f1,func(x0+inc*soma*d),i)
            break
        elif func(x0+inc*(soma)*d) > f1 and i == 0:
            inc = inc / 10
    I = inc * m**(i-1)*(1+m)
    T = (np.sqrt(5) - 1)/2
    Au = inc * (soma)
    Al = inc * (soma - m**i*(1+1/m))
    Ab = T * I + Al
    Aa = (1-T) * I + Al
    fa = func(x0+Aa*d)
    fb = func(x0+Ab*d)
    while I > 1e-3:
        if fa < fb:
            Au, Ab = Ab, Aa    
            Aa = Al + (1-T) * (Au-Al)
            fb, fa = fa, func(x0+Aa*d)
        elif fa > fb:
            Al, Aa = Aa, Ab            
            Ab = T * (Au-Al) + Al
            fa, fb = fb, func(x0+Ab*d)
        else:
            Al,Au = Aa, Ab            
            Ab = T * (Au-Al) + Al
            Aa = (1-T) * (Au-Al) + Al
            fa = func(x0+Aa*d)
            fb = func(x0+Ab*d)
        I = Au - Al
    A = 0.5*(Au+Al)
    return(A)

# %% [markdown]
# #### Função teste
#
# * Rosenbrock's banana function

# %%
xx = np.linspace(-3,3,1000)
yy = np.linspace(-2,4,1000)
x1,x2 = np.meshgrid(xx,yy)
Z = 10*x1**4 - x2*20*x1**2 +\
           10*x2**2 + x1**2 -2*x1 + 5

levels = [4.007,4.25,5,7.5,10,15,30,40,60,100,150,200]
cors = ('#FF4500','#696969','#6495ED')*4
plt.figure(figsize=(8,4))
cp = plt.contour(x1,x2,Z,levels,colors=cors)
plt.clabel(cp, inline=True,fontsize=10)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Rosenbrock's banana function")

# %% [markdown]
# Algoritmo de minimização

# %%
epsilon = 1e-5
x0 = [3,-1]
f,df,d2f = func(x0), grad(x0), hess(x0)#np.eye(2)
print(np.linalg.norm(df))
x = x0
i = 0
xp,yp,fp = [x0[0]], [x0[1]], [f]
d = direction(x,1,d2f=d2f)[0]
d1,d2 = [d[0]],[d[1]]
inc = 0.1
a = step(x,d,inc)

while np.linalg.norm(df) > epsilon and i < 3000:
    if func(x + a*d) <= f:
        x += a*d                
        f,df = func(x), grad(x)
        a = step(x,d,inc)        
    else:
        d = direction(x,1,a,d2f=d2f)[0]
        #print(np.dot(d,df)<-0.05*np.linalg.norm(df)*np.linalg.norm(d),'\n')
        #print(np.linalg.norm(df)*0.001 < np.linalg.norm(d))
        d1.append(d[0]),d2.append(d[1])
        xp.append(x[0]),yp.append(x[1])
        d2f = hess_num(x,df,a,d,d2f)
    if np.linalg.norm(df) == 0 and all(np.linalg.eigvals(d2f) > 0):
        print('x é minimizador')
        break    
    a = step(x,d,inc)
    i += 1  
print(x,f,i,np.linalg.norm(df))

plt.figure(figsize=(10,5))
cp = plt.contour(x1,x2,Z,levels,colors=cors)
plt.plot(xp,yp,'ro-')
#plt.quiver(x0[0],x0[1],grad(x0)[0],grad(x0)[1])
#plt.quiver(x[0],x[1],grad(x)[0],grad(x)[1])
#plt.quiver(xp,yp,d1,d2,color='None',linewidths=(1,),edgecolors=('k'))
#plt.quiver(xp,yp,dfp1,dfp2,color='None',linewidths=(1,),edgecolors=('r'))
plt.clabel(cp, inline=True,fontsize=10)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Rosenbrock's banana function")
plt.axis([-3,3,-2,4])
# Out:
# 12169.4706541
# [ 1.00000016  1.00000032] 2.59587626464e-14 60 1.31034374578e-06
# [-3, 3, -2, 4]

# %%
x0,x,x+a*d/10,a,d,df,i,np.linalg.norm(df)
# Out:
# ([-1.5, -0.5],
#  array([-1.49637024,  1.68911071]),
#  array([ 25.23979603,  10.48932151]),
#  0.8,
#  array([ 334.20207836,  110.00263504]),
#  array([[-334.20207836],
#         [-110.00263504]]),
#  500,
#  351.84031732558736)

# %%
func(x0),func(x0+d),func(x+a*d),func(x+d*(a*0.9))
# Out:
# (756.5, 173.00809762252109, 0.067572815410618242, 0.067564390889312029)

# %%
d,df,np.linalg.norm(d),np.linalg.norm(df)
# Out:
# (array([ 0.00866182, -0.00323386]), array([[-0.00033622],
#         [-0.00092474]]), 0.009245808333923973, 0.00098396805003937151)

# %%
np.matmul(df.T,d.reshape(2,1)),np.linalg.norm(df)*np.linalg.norm(d)
# Out:
# (array([[  7.81864562e-08]]), 9.0975799973689423e-06)

# %%
f1 = func(x0)
m = (np.sqrt(5) + 1) / 2
soma = 0
inc = 0.05
alpha = 1
for i in range(30):
    print(soma)
    soma += m**i
    if func(x0+inc*soma*d) > f1:
        I = inc * m**(i-1)*(1 + m)
        print(i,I,f1,func(x0+inc*(soma-m**i*(1+1/m))*d))
        break
# Out:
# 0
# 1.0
# 2.61803398875
# 5.2360679775
# 9.472135955
# 16.3262379212
# 27.416407865
# 45.360679775
# 74.3951216287
# 8 3.80065778087 756.5 30.0655367023

# %%
inc*(1+soma),inc*(soma-m**i*(1+1/m)),I
# Out:
# (3.0103483819663457, 1.1498493819668816, 1.8604979999994642)

# %%
d[0]
# Out:
# -9.7524792592511904
